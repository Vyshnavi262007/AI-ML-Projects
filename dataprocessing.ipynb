# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyshnavi262007/AI-ML-Projects/blob/main/dataprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
import pandas as pd
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['Target'] = iris.target

# Check the first few rows
df.head()

# Check for null values
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Target               0
# dtype: int64

# %%
from matplotlib import pyplot as plt
df['sepal length (cm)'].plot(kind='hist',bins=20,title='sepal length (cm)')
plt.show()

# %%
from matplotlib import pyplot as plt
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'])
plt.title("Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.xlim([4,7])
plt.ylim([2,4.5])
plt.show()

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      Target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# Target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    Target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# Target                     0.956547  1.000000

# %%
df.corr(method='spearman')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.166778           0.881898
# sepal width (cm)           -0.166778          1.000000          -0.309635
# petal length (cm)           0.881898         -0.309635           1.000000
# petal width (cm)            0.834289         -0.289032           0.937667
# Target                      0.798078         -0.440290           0.935431
#
#                    petal width (cm)    Target
# sepal length (cm)          0.834289  0.798078
# sepal width (cm)          -0.289032 -0.440290
# petal length (cm)          0.937667  0.935431
# petal width (cm)           1.000000  0.938179
# Target                     0.938179  1.000000

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'Target'],
#       dtype='object')

# %%
df['petal length (cm)']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal length (cm), Length: 150, dtype: float64

# %%
df['Target']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Target, Length: 150, dtype: int64

# %%
df[['sepal length (cm)', 'sepal width (cm)']]
# Out:
#      sepal length (cm)  sepal width (cm)
# 0                  5.1               3.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# 4                  5.0               3.6
# ..                 ...               ...
# 145                6.7               3.0
# 146                6.3               2.5
# 147                6.5               3.0
# 148                6.2               3.4
# 149                5.9               3.0
#
# [150 rows x 2 columns]

# %%
df[['sepal length (cm)', 'sepal width (cm)','petal length (cm)']]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)
# 0                  5.1               3.5                1.4
# 1                  4.9               3.0                1.4
# 2                  4.7               3.2                1.3
# 3                  4.6               3.1                1.5
# 4                  5.0               3.6                1.4
# ..                 ...               ...                ...
# 145                6.7               3.0                5.2
# 146                6.3               2.5                5.0
# 147                6.5               3.0                5.2
# 148                6.2               3.4                5.4
# 149                5.9               3.0                5.1
#
# [150 rows x 3 columns]

# %%
df.loc[3:5,['sepal length (cm)', 'sepal width (cm)']]
# Out:
#    sepal length (cm)  sepal width (cm)
# 3                4.6               3.1
# 4                5.0               3.6
# 5                5.4               3.9

# %%
df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)','petal width (cm)']]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.loc[3:5,['sepal length (cm)', 'sepal width (cm)']]
df.iloc[3:5,0:3] #if we don't know the name
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)
# 3                4.6               3.1                1.5
# 4                5.0               3.6                1.4
